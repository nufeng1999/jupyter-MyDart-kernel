# %%
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        // widgets -> 单子元素 ;
        // widgets -> 多子元素 ;
        单子元素 -> Container ;
        单子元素 -> Padding
        单子元素 -> Center
        单子元素 -> Align
        单子元素 -> AspectRatio
        单子元素 -> SingleChildScrollView ;
        单子元素 -> FittedBox ;
        单子元素 -> FractionallySizedBox ;
        单子元素 -> ConstrainedBox ;
        单子元素 -> Baseline ;
        单子元素 -> IntrinsicWidth
        单子元素 -> IntrinsicHeight ;

        多子元素 -> Row ;
        多子元素 -> Column ;
        多子元素 -> Wrap ;
        多子元素 -> Stack ;
        多子元素 -> IndexedStack ;
        多子元素 -> Flow ;
        多子元素 -> Table ;
        多子元素 -> ListBody ;
        多子元素 -> ListView ;

        可滚动Widget -> SingleChildScrollView ;
        可滚动Widget -> ListView ;
        可滚动Widget -> GridView ;
        可滚动Widget -> CustomScrollView ;
        可滚动Widget -> PageView ;
        可滚动Widget -> Slivers ;

        拥有单个子元素的布局widget -> Container ;
        拥有单个子元素的布局widget -> Padding ;
        拥有单个子元素的布局widget -> Center ;
        拥有单个子元素的布局widget -> Align ;
        拥有单个子元素的布局widget -> FittedBox ;
        拥有单个子元素的布局widget -> AspectRatio ;
        拥有单个子元素的布局widget -> ConstrainedBox ;
        拥有单个子元素的布局widget -> Baseline ;
        拥有单个子元素的布局widget -> FractionallySizedBox ;
        拥有单个子元素的布局widget -> IntrinsicHeight ;
        拥有单个子元素的布局widget -> IntrinsicWidth ;
        拥有单个子元素的布局widget -> LimitedBox ;
        拥有单个子元素的布局widget -> Offstage ;
        拥有单个子元素的布局widget -> OverflowBox ;
        拥有单个子元素的布局widget -> SizedBox ;
        拥有单个子元素的布局widget -> SizedOverflowBox ;
        拥有单个子元素的布局widget -> Transform ;
        拥有单个子元素的布局widget -> CustomSingleChildLayout ;
        
        拥有多个子元素的布局widget -> Row ;
        拥有多个子元素的布局widget -> Column ;
        拥有多个子元素的布局widget -> Stack ;
        拥有多个子元素的布局widget -> IndexedStack ;
        拥有多个子元素的布局widget -> Flow ;
        拥有多个子元素的布局widget -> Table ;
        拥有多个子元素的布局widget -> Wrap ;
        拥有多个子元素的布局widget -> ListBody ;
        拥有多个子元素的布局widget -> ListView ;
        拥有多个子元素的布局widget -> CustomMultiChildLayout ;

        "Layout helpers" -> LayoutBuilder  ;
    }
}

# %%
// 单子元素
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        // widgets -> 单子元素 ;
        // widgets -> 多子元素 ;
        单子元素 -> Container ;
        单子元素 -> Padding
        单子元素 -> Center
        单子元素 -> Align
        单子元素 -> AspectRatio
        单子元素 -> SingleChildScrollView ;
        单子元素 -> FittedBox ;
        单子元素 -> FractionallySizedBox ;
        单子元素 -> ConstrainedBox ;
        单子元素 -> Baseline ;
        单子元素 -> IntrinsicWidth
        单子元素 -> IntrinsicHeight ;
    }
}

# %%
// 多子元素
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        多子元素 -> Row ;
        多子元素 -> Column ;
        多子元素 -> Wrap ;
        多子元素 -> Stack ;
        多子元素 -> IndexedStack ;
        多子元素 -> Flow ;
        多子元素 -> Table ;
        多子元素 -> ListBody ;
        多子元素 -> ListView ;
    }
}
# Out:
# [MyDotKernel102135] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel102135] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// 可滚动Widget
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        可滚动Widget -> SingleChildScrollView ;
        可滚动Widget -> "ListView" ;
        可滚动Widget -> GridView ;
        可滚动Widget -> CustomScrollView ;
        可滚动Widget -> PageView ;
        可滚动Widget -> Slivers ;
    }
}
# Out:
# [MyDotKernel102135] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel102135] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// 拥有单个子元素的布局widget
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        拥有单个子元素的布局widget -> Container ;
        拥有单个子元素的布局widget -> Padding ;
        拥有单个子元素的布局widget -> Center ;
        拥有单个子元素的布局widget -> Align ;
        拥有单个子元素的布局widget -> FittedBox ;
        拥有单个子元素的布局widget -> AspectRatio ;
        拥有单个子元素的布局widget -> ConstrainedBox ;
        拥有单个子元素的布局widget -> Baseline ;
        拥有单个子元素的布局widget -> FractionallySizedBox ;
        拥有单个子元素的布局widget -> IntrinsicHeight ;
        拥有单个子元素的布局widget -> IntrinsicWidth ;
        拥有单个子元素的布局widget -> LimitedBox ;
        拥有单个子元素的布局widget -> Offstage ;
        拥有单个子元素的布局widget -> OverflowBox ;
        拥有单个子元素的布局widget -> SizedBox ;
        拥有单个子元素的布局widget -> SizedOverflowBox ;
        拥有单个子元素的布局widget -> Transform ;
        拥有单个子元素的布局widget -> CustomSingleChildLayout ;
    }
}
# Out:
# [MyDotKernel215619] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel215619] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// 拥有多个子元素的布局widget
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong"];
    node [ fontname="FangSong"];
    {        
        拥有多个子元素的布局widget -> Row ;
        拥有多个子元素的布局widget -> Column ;
        拥有多个子元素的布局widget -> Stack ;
        拥有多个子元素的布局widget -> IndexedStack ;
        拥有多个子元素的布局widget -> Flow ;
        拥有多个子元素的布局widget -> Table ;
        拥有多个子元素的布局widget -> Wrap ;
        拥有多个子元素的布局widget -> ListBody ;
        拥有多个子元素的布局widget -> ListView ;
        拥有多个子元素的布局widget -> CustomMultiChildLayout ;

        "Layout helpers" -> LayoutBuilder  ;
    }
}
# Out:
# [MyDotKernel215619] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel215619] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// 拥有多个子元素的布局widget
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    rankdir="LR";
    edge [fontname="FangSong"];
    node [ fontname="FangSong"];
    {        
        特效widget -> InkWell ;
        特效widget -> Ink ;
    }
}
# Out:
# [MyDotKernel085442] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel085442] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// Material Components Widgets
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph Material{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {        
        MaterialApp ;
        WidgetsApp ;
        Drawer ;
        按钮 -> RaisedButton ;
        按钮 -> FloatingActionButton ;
        按钮 -> FlatButton ;
        按钮 -> IconButton ;
        按钮 -> PopupMenuButton ;
        按钮 -> ButtonBar ;

        输入框和选择框 -> TextField ;
        输入框和选择框 -> Checkbox ;
        输入框和选择框 -> Radio ;
        输入框和选择框 -> Switch ;
        输入框和选择框 -> Slider ;
        输入框和选择框 -> "Date & Time Pickers" ;

        "信息展示" -> Image ;
        "信息展示" -> Icon ;
        "信息展示" -> Chip ;
        "信息展示" -> Tooltip ;
        "信息展示" -> DataTable ;
        "信息展示" -> Card ;
        "信息展示" -> LinearProgressIndicator ;

        "对话框、Alert、Panel" -> SimpleDialog ;
        "对话框、Alert、Panel" -> AlertDialog ;
        "对话框、Alert、Panel" -> BottomSheet ;
        "对话框、Alert、Panel" -> ExpansionPanel ;
        "对话框、Alert、Panel" -> SnackBar ;

        布局-> ListTile ;
        布局-> Stepper ;
        布局-> Divider ;

        Material -> Scaffold ;
        Material -> Appbar ;
        Material -> BottomNavigationBar ;
        Material -> TabBar ;
        Material -> TabBarView ;
        Material -> Table ;
        Material -> Wrap ;
        Material -> ListBody ;
        Material -> ListView ;
        Material -> CustomMultiChildLayout ;

        "Layout helpers" -> LayoutBuilder  ;
    }
}
# Out:
# [MyDotKernel102135] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel102135] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot

# %%
// Material Components Widgets
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph Material{
    rankdir="LR";
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        Widget->Element1
        Widget->Element2
        Widget->ElementN
        ElementN->RenderObject 
        RenderObject ->ElementN
    }
}
# Out:
# [MyDotKernel135031] Info:file h:\Jupyter\ipynb\MyDart\src/test1.dot created successfully
# [MyDotKernel135031] Info:The process :h:\Jupyter\ipynb\MyDart\src/test1.dot
